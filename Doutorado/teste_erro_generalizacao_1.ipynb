# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import math
from numpy.random import rand
from numpy.random import randn
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import sklearn.metrics
from sklearn.metrics import mean_absolute_percentage_error

# %%
x_limite_inferior = 1
y_limite_inferior = 1
x_limite_superior = 100
y_limite_superior = 100
qtdd_amostras = 10000

# %%
X = np.random.randint(x_limite_inferior, x_limite_superior, (qtdd_amostras))
Y = np.random.randint(y_limite_inferior, y_limite_superior, (qtdd_amostras))

# %%
def function(X,Y):
    return X * Y

# %%
Z = function(X,Y)

# %%
# ---------------------- Informação a Priori ---------------------- 
df = pd.DataFrame(Z, columns = ['Z'])

df['X'] = X

df['Y'] = Y

# %%
# ---------------- Escolha dos parametros de entrada para a Rede Neural ----------------
columns_features_train = ['X', 'Y']

columns_features_predict = columns_features_train

input_numbers = len(columns_features_train)

target_train = ['Z']

# %%
# ---------------- Configuração da rede neural ----------------
model = Sequential()
model.add(Dense(units = 1 * input_numbers, activation = 'linear', input_dim=input_numbers))
model.add(Dense(units = 100, activation = 'relu'))
model.add(Dense(units = 100, activation = 'relu'))
model.add(Dense(units = 1, activation = 'linear'))
model.compile(loss='mse', optimizer="adam")

# %%
# ---------------- treinamento da rede ----------------
model.fit(df_train[columns_features_train], df_train[target_train],
          epochs=50, verbose=1, use_multiprocessing=True)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 2s 4ms/step - loss: 45.7358
# Epoch 2/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.9062
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1040
# Epoch 4/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0304
# Epoch 5/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0206
# Epoch 6/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0162
# Epoch 7/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0133
# Epoch 8/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 9/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 10/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 11/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 12/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0059
# ...

# %%
# ---------------- Previsão dos dados de teste ----------------
Y_Predict = model.predict(df_test[columns_features_train])
Y_Predict.shape

df_test['Y_Predict'] = pd.DataFrame(Y_Predict)

df_test.head(50)
# Out:
# 7/7 [==============================] - 0s 3ms/step
#      X  Y   Z  Y_Predict
# 300  4  7  11        NaN
# 647  2  1   3        NaN
# 94   2  8  10  14.997954
# 360  1  4   5        NaN
# 218  5  5  10        NaN
# 676  2  2   4        NaN
# 580  7  1   8        NaN
# 146  9  8  17  11.997046
# 599  2  7   9        NaN
# 819  3  4   7        NaN
# 137  7  3  10  11.001368
# 941  8  9  17        NaN
# 33   6  3   9   5.004322
# 554  5  2   7        NaN
# 514  9  9  18        NaN
# 583  4  7  11        NaN
# 69   5  9  14   9.999774
# 331  3  7  10        NaN
# 753  8  5  13        NaN
# 471  4  7  11        NaN
# 371  2  1   3        NaN
# 968  2  2   4        NaN
# 562  9  9  18        NaN
# 531  2  4   6        NaN
# 263  6  9  15        NaN
# 171  5  6  11   9.999774
# 354  3  2   5        NaN
# 342  9  9  18        NaN
# 402  5  2   7        NaN
# 184  4  2   6   9.000113
# 851  1  1   2        NaN
# 357  3  2   5        NaN
# 720  7  1   8        NaN
# 18   4  1   5  12.998078
# ...

# %%
mape = mean_absolute_percentage_error(df_test['Y'], df_test['Y_Predict'])

print(f'Mean Square Percentage Error: {mape.round(2)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [312], in <cell line: 1>()
# ----> 1 mape = mean_absolute_percentage_error(df_test['Y'], df_test['Y_Predict'])
#       3 print(f'Mean Square Percentage Error: {mape.round(2)}')
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:65, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      63 extra_args = len(args) - len(all_args)
#      64 if extra_args <= 0:
# ---> 65     return f(*args, **kwargs)
#      67 # extra_args > 0
#      68 args_msg = [
#      69     "{}={}".format(name, arg)
#      70     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      71 ]
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:361, in mean_absolute_percentage_error(y_true, y_pred, sample_weight, multioutput)
# ...

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# This builds the model for the first time:
model.fit(df_train[feature_columns], df_train[target_columns], batch_size=1024, epochs=200)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [287], in <cell line: 2>()
#       1 # This builds the model for the first time:
# ----> 2 model.fit(df_train[feature_columns], df_train[target_columns], batch_size=1024, epochs=200)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
#import data_creation as dc 

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(2,)),
    keras.layers.Dense(20, activation=tf.nn.relu),
    keras.layers.Dense(20, activation=tf.nn.relu),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', 
              loss='mse',
              metrics=['mae'])
model.fit(df_train[feature_columns], df_train[target_columns], batch_size=1024, epochs=200)
#model.fit(dc.train_data, dc.train_targets, epochs=10, batch_size=1)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 1s/step - loss: 143.9823 - mae: 11.2584
# Epoch 2/200
# 1/1 [==============================] - 0s 8ms/step - loss: 141.5274 - mae: 11.1607
# Epoch 3/200
# 1/1 [==============================] - 0s 5ms/step - loss: 139.0936 - mae: 11.0630
# Epoch 4/200
# 1/1 [==============================] - 0s 5ms/step - loss: 136.6818 - mae: 10.9653
# Epoch 5/200
# 1/1 [==============================] - 0s 6ms/step - loss: 134.2838 - mae: 10.8673
# Epoch 6/200
# 1/1 [==============================] - 0s 6ms/step - loss: 131.9069 - mae: 10.7693
# Epoch 7/200
# 1/1 [==============================] - 0s 5ms/step - loss: 129.5555 - mae: 10.6714
# Epoch 8/200
# 1/1 [==============================] - 0s 5ms/step - loss: 127.2245 - mae: 10.5734
# Epoch 9/200
# 1/1 [==============================] - 0s 6ms/step - loss: 124.9178 - mae: 10.4755
# Epoch 10/200
# 1/1 [==============================] - 0s 6ms/step - loss: 122.6310 - mae: 10.3776
# ...

# %%
# ---------------- Previsão dos dados de teste ----------------
Z_Predict = model.predict(df_test[feature_columns])

df_test['Z_Predict'] = pd.DataFrame(Z_Predict)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
df_test.head(50)
# Out:
#      X  Y   Z  Z_Predict
# 935  2  1   3        NaN
# 811  5  3   8        NaN
# 344  3  5   8        NaN
# 629  2  2   4        NaN
# 746  8  8  16        NaN
# 243  8  8  16        NaN
# 331  3  7  10        NaN
# 874  1  8   9        NaN
# 346  8  5  13        NaN
# 512  1  8   9        NaN
# 115  1  2   3   7.354910
# 292  2  2   4        NaN
# 705  4  4   8        NaN
# 183  4  4   8   9.689663
# 251  7  9  16        NaN
# 389  3  5   8        NaN
# 423  4  9  13        NaN
# 214  7  9  16        NaN
# 878  5  5  10        NaN
# 302  2  9  11        NaN
# 690  4  5   9        NaN
# 685  7  7  14        NaN
# 742  9  8  17        NaN
# 339  7  9  16        NaN
# 922  6  8  14        NaN
# 578  7  2   9        NaN
# 386  3  3   6        NaN
# 400  5  3   8        NaN
# 136  8  9  17   3.512730
# 41   9  6  15  11.506775
# 515  3  4   7        NaN
# 366  8  1   9        NaN
# 919  2  6   8        NaN
# 80   4  9  13  15.047135
# 665  7  3  10        NaN
# 560  2  8  10        NaN
# ...

# %%
# Métricas de erro

mse = mean_squared_error(df_test['Z'], df_test['Z_Predict'])

r2_score = sklearn.metrics.r2_score(df_test['Z'], df_test['Z_Predict'])

print(f'Mean Square Error: {mse.round(2)}, R²: {r2_score.round(2)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [274], in <cell line: 3>()
#       1 # Métricas de erro
# ----> 3 mse = mean_squared_error(df_test['Z'], df_test['Z_Predict'])
#       5 r2_score = sklearn.metrics.r2_score(df_test['Z'], df_test['Z_Predict'])
#       7 print(f'Mean Square Error: {mse.round(2)}, R²: {r2_score.round(2)}')
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:438, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     378 def mean_squared_error(
#     379     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     380 ):
#     381     """Mean squared error regression loss.
#     382
#     383     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     436     0.825...
#     437     """
# ...

# %%
f
