# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import math
from numpy.random import rand
from numpy.random import randn
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import sklearn.metrics

# %%
x_limite_inferior = 1
y_limite_inferior = 1
x_limite_superior = 10
y_limite_superior = 10
qtdd_amostras = 1000

# %%
X = np.random.randint(x_limite_inferior, x_limite_superior, (qtdd_amostras))
Y = np.random.randint(y_limite_inferior, y_limite_superior, (qtdd_amostras))

# %%
def function(X,Y):
    return X + Y

# %%
Z = function(X,Y)

# %%
matrix_aux = np.vstack([X,Y,Z])
matrix = np.transpose(matrix_aux)

# %%
df = pd.DataFrame(matrix, columns = ['X', 'Y','Z'])

df.head()
# Out:
#    X  Y   Z
# 0  7  9  16
# 1  9  7  16
# 2  5  2   7
# 3  2  1   3
# 4  5  1   6

# %%
feature_columns = ['X','Y']
target_columns = ['Z']
input_numbers = len(feature_columns)
output_numbers = len(target_columns)

print(input_numbers)
print(output_numbers)
# Out:
# 2
# 1

# %%
df_train, df_test = train_test_split(df, test_size=0.2)

# %%
model = Sequential()
#model.add(Dense(units = 2 * input_numbers, activation = 'linear', input_dim=input_numbers))
numeros_neuronios_layer = [2]
for i in numeros_neuronios_layer:
    model.add(Dense(i, activation="linear"))
model.add(Dense(2, activation="linear"))

# %%
#df_train[target_columns]
df_test[feature_columns]
# Out:
#      X  Y
# 935  2  1
# 811  5  3
# 344  3  5
# 629  2  2
# 746  8  8
# ..  .. ..
# 589  9  5
# 730  8  5
# 324  5  3
# 855  3  6
# 662  6  9
#
# [200 rows x 2 columns]

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# This builds the model for the first time:
model.fit(df_train[feature_columns], df_train[target_columns], batch_size=1024, epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 558ms/step - loss: 154.2908
# Epoch 2/200
# 1/1 [==============================] - 0s 5ms/step - loss: 115.4347
# Epoch 3/200
# 1/1 [==============================] - 0s 6ms/step - loss: 102.8721
# Epoch 4/200
# 1/1 [==============================] - 0s 6ms/step - loss: 86.0915
# Epoch 5/200
# 1/1 [==============================] - 0s 5ms/step - loss: 44.2429
# Epoch 6/200
# 1/1 [==============================] - 0s 3ms/step - loss: 11.4057
# Epoch 7/200
# 1/1 [==============================] - 0s 4ms/step - loss: 8.0705
# Epoch 8/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.1219
# Epoch 9/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2715
# Epoch 10/200
# 1/1 [==============================] - 0s 5ms/step - loss: 4.9031
# Epoch 11/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.1661
# Epoch 12/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.5396
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
#import data_creation as dc 

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(2,)),
    keras.layers.Dense(20, activation=tf.nn.relu),
    keras.layers.Dense(20, activation=tf.nn.relu),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', 
              loss='mse',
              metrics=['mae'])
model.fit(df_train[feature_columns], df_train[target_columns], batch_size=1024, epochs=200)
#model.fit(dc.train_data, dc.train_targets, epochs=10, batch_size=1)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 1s/step - loss: 143.9823 - mae: 11.2584
# Epoch 2/200
# 1/1 [==============================] - 0s 8ms/step - loss: 141.5274 - mae: 11.1607
# Epoch 3/200
# 1/1 [==============================] - 0s 5ms/step - loss: 139.0936 - mae: 11.0630
# Epoch 4/200
# 1/1 [==============================] - 0s 5ms/step - loss: 136.6818 - mae: 10.9653
# Epoch 5/200
# 1/1 [==============================] - 0s 6ms/step - loss: 134.2838 - mae: 10.8673
# Epoch 6/200
# 1/1 [==============================] - 0s 6ms/step - loss: 131.9069 - mae: 10.7693
# Epoch 7/200
# 1/1 [==============================] - 0s 5ms/step - loss: 129.5555 - mae: 10.6714
# Epoch 8/200
# 1/1 [==============================] - 0s 5ms/step - loss: 127.2245 - mae: 10.5734
# Epoch 9/200
# 1/1 [==============================] - 0s 6ms/step - loss: 124.9178 - mae: 10.4755
# Epoch 10/200
# 1/1 [==============================] - 0s 6ms/step - loss: 122.6310 - mae: 10.3776
# ...

# %%
# ---------------- Previsão dos dados de teste ----------------
Z_Predict = model.predict(df_test[feature_columns])

df_test['Z_Predict'] = pd.DataFrame(Z_Predict)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
df_test.head(50)
# Out:
#      X  Y   Z  Z_Predict
# 935  2  1   3        NaN
# 811  5  3   8        NaN
# 344  3  5   8        NaN
# 629  2  2   4        NaN
# 746  8  8  16        NaN
# 243  8  8  16        NaN
# 331  3  7  10        NaN
# 874  1  8   9        NaN
# 346  8  5  13        NaN
# 512  1  8   9        NaN
# 115  1  2   3   7.354910
# 292  2  2   4        NaN
# 705  4  4   8        NaN
# 183  4  4   8   9.689663
# 251  7  9  16        NaN
# 389  3  5   8        NaN
# 423  4  9  13        NaN
# 214  7  9  16        NaN
# 878  5  5  10        NaN
# 302  2  9  11        NaN
# 690  4  5   9        NaN
# 685  7  7  14        NaN
# 742  9  8  17        NaN
# 339  7  9  16        NaN
# 922  6  8  14        NaN
# 578  7  2   9        NaN
# 386  3  3   6        NaN
# 400  5  3   8        NaN
# 136  8  9  17   3.512730
# 41   9  6  15  11.506775
# 515  3  4   7        NaN
# 366  8  1   9        NaN
# 919  2  6   8        NaN
# 80   4  9  13  15.047135
# 665  7  3  10        NaN
# 560  2  8  10        NaN
# ...

# %%
# Métricas de erro

mse = mean_squared_error(df_test['Z'], df_test['Z_Predict'])

r2_score = sklearn.metrics.r2_score(df_test['Z'], df_test['Z_Predict'])

print(f'Mean Square Error: {mse.round(2)}, R²: {r2_score.round(2)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [274], in <cell line: 3>()
#       1 # Métricas de erro
# ----> 3 mse = mean_squared_error(df_test['Z'], df_test['Z_Predict'])
#       5 r2_score = sklearn.metrics.r2_score(df_test['Z'], df_test['Z_Predict'])
#       7 print(f'Mean Square Error: {mse.round(2)}, R²: {r2_score.round(2)}')
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:438, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     378 def mean_squared_error(
#     379     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     380 ):
#     381     """Mean squared error regression loss.
#     382
#     383     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     436     0.825...
#     437     """
# ...

# %%
f
